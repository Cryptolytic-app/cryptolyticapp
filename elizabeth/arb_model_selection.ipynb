# %%
import glob
import os
import pickle
import json
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import datetime as dt

# %%
perf_csv_paths = glob.glob('model_performance/*.csv')[:5]
len(perf_csv_paths)
# print(perf_csv_paths[:5])
# Out:
# 5

# %%
def concat_dfs(filepaths):
    
    df_list = []
    for path in filepaths:
        df = pd.read_csv(path)
        df_list.append(df)
    
    df = pd.concat(df_list)
    df = df.sort_values(by='pct_profit_mean', ascending=False)
    
    return df

# %%
perf_df = concat_dfs(perf_csv_paths)
print(perf_df.shape)
perf_df.head(50)
df3 = perf_df.drop_duplicates()
df3.shape
# Out:
# (76, 5)
# (76, 5)

# %%
good_models = perf_df[perf_df['pct_profit_mean'] > 0.3]
good_models

ex_tp = good_models.ex_tp.values
max_features = good_models.max_features.values
max_depth = good_models.max_depth.values
good_model_names = []
for i in range(len(ex_tp)):
    model_name = ex_tp[i] + '_' + str(max_features[i]) + '_' + str(max_depth[i])
    good_model_names.append(model_name)
    
print(len(good_model_names))
# Out:
# 29

# %%
confusion_paths = glob.glob('confusion_json/*.json')
print(len(confusion_paths))
# Out:
# 5

# %%
def concat_dicts(filepaths):
    
    confusion_dict = {}
    
    for path in filepaths:
        confusion = json.load(open(path))
        confusion_dict.update(confusion)
    
    return confusion_dict

# %%
confusion_dict = concat_dicts(confusion_paths)
print(len(confusion_dict))
# Out:
# 1520

# %%
confusion_dict[good_model_names[0]]
confusion_matrix = pd.read_json(confusion_dict[good_model_names[0]])
confusion_matrix['Predicted 0']
# Out:
# 0       11
# 1    19651
# 2        4
# Name: Predicted 0, dtype: int64

# %%
confusion_dict.keys()
# Out:
# dict_keys(['bitfinex_gemini_ltc_btc_40_17', 'bitfinex_gemini_ltc_btc_45_17', 'bitfinex_gemini_ltc_btc_50_17', 'bitfinex_gemini_ltc_btc_55_17', 'bitfinex_gemini_ltc_btc_60_17', 'bitfinex_gemini_ltc_btc_40_20', 'bitfinex_gemini_ltc_btc_45_20', 'bitfinex_gemini_ltc_btc_50_20', 'bitfinex_gemini_ltc_btc_55_20', 'bitfinex_gemini_ltc_btc_60_20', 'bitfinex_gemini_ltc_btc_40_25', 'bitfinex_gemini_ltc_btc_45_25', 'bitfinex_gemini_ltc_btc_50_25', 'bitfinex_gemini_ltc_btc_55_25', 'bitfinex_gemini_ltc_btc_60_25', 'bitfinex_gemini_ltc_btc_40_27', 'bitfinex_gemini_ltc_btc_45_27', 'bitfinex_gemini_ltc_btc_50_27', 'bitfinex_gemini_ltc_btc_55_27', 'bitfinex_gemini_ltc_btc_60_27', 'coinbase_pro_hitbtc_xrp_btc_40_17', 'coinbase_pro_hitbtc_xrp_btc_45_17', 'coinbase_pro_hitbtc_xrp_btc_50_17', 'coinbase_pro_hitbtc_xrp_btc_55_17', 'coinbase_pro_hitbtc_xrp_btc_60_17', 'coinbase_pro_hitbtc_xrp_btc_40_20', 'coinbase_pro_hitbtc_xrp_btc_45_20', 'coinbase_pro_hitbtc_xrp_btc_50_20', 'coinbase_pro_hitbtc_xrp_btc_55_20', 'coinbase_pro_hitbtc_xrp_btc_60_20', 'coinbase_pro_hitbtc_xrp_btc_40_25', 'coinbase_pro_hitbtc_xrp_btc_45_25', 'coinbase_pro_hitbtc_xrp_btc_50_25', 'coinbase_pro_hitbtc_xrp_btc_55_25', 'coinbase_pro_hitbtc_xrp_btc_60_25', 'coinbase_pro_hitbtc_xrp_btc_40_27', 'coinbase_pro_hitbtc_xrp_btc_45_27', 'coinbase_pro_hitbtc_xrp_btc_50_27', 'coinbase_pro_hitbtc_xrp_btc_55_27', 'coinbase_pro_hitbtc_xrp_btc_60_27', 'kraken_hitbtc_bch_btc_40_17', 'kraken_hitbtc_bch_btc_45_17', 'kraken_hitbtc_bch_btc_50_17', 'kraken_hitbtc_bch_btc_55_17', 'kraken_hitbtc_bch_btc_60_17', 'kraken_hitbtc_bch_btc_40_20', 'kraken_hitbtc_bch_btc_45_20', 'kraken_hitbtc_bch_btc_50_20', 'kraken_hitbtc_bch_btc_55_20', 'kraken_hitbtc_bch_btc_60_20', 'kraken_hitbtc_bch_btc_40_25', 'kraken_hitbtc_bch_btc_45_25', 'kraken_hitbtc_bch_btc_50_25', 'kraken_hitbtc_bch_btc_55_25', 'kraken_hitbtc_bch_btc_60_25', 'kraken_hitbtc_bch_btc_40_27', 'kraken_hitbtc_bch_btc_45_27', 'kraken_hitbtc_bch_btc_50_27', 'kraken_hitbtc_bch_btc_55_27', 'kraken_hitbtc_bch_btc_60_27', 'kraken_gemini_zec_usd_40_17', 'kraken_gemini_zec_usd_45_17', 'kraken_gemini_zec_usd_50_17', 'kraken_gemini_zec_usd_55_17', 'kraken_gemini_zec_usd_60_17', 'kraken_gemini_zec_usd_40_20', 'kraken_gemini_zec_usd_45_20', 'kraken_gemini_zec_usd_50_20', 'kraken_gemini_zec_usd_55_20', 'kraken_gemini_zec_usd_60_20', 'kraken_gemini_zec_usd_40_25', 'kraken_gemini_zec_usd_45_25', 'kraken_gemini_zec_usd_50_25', 'kraken_gemini_zec_usd_55_25', 'kraken_gemini_zec_usd_60_25', 'kraken_gemini_zec_usd_40_27', 'kraken_gemini_zec_usd_45_27', 'kraken_gemini_zec_usd_50_27', 'kraken_gemini_zec_usd_55_27', 'kraken_gemini_zec_usd_60_27', 'bitfinex_coinbase_pro_ltc_usd_40_17', 'bitfinex_coinbase_pro_ltc_usd_45_17', 'bitfinex_coinbase_pro_ltc_usd_50_17', 'bitfinex_coinbase_pro_ltc_usd_55_17', 'bitfinex_coinbase_pro_ltc_usd_60_17', 'bitfinex_coinbase_pro_ltc_usd_40_20', 'bitfinex_coinbase_pro_ltc_usd_45_20', 'bitfinex_coinbase_pro_ltc_usd_50_20', 'bitfinex_coinbase_pro_ltc_usd_55_20', 'bitfinex_coinbase_pro_ltc_usd_60_20', 'bitfinex_coinbase_pro_ltc_usd_40_25', 'bitfinex_coinbase_pro_ltc_usd_45_25', 'bitfinex_coinbase_pro_ltc_usd_50_25', 'bitfinex_coinbase_pro_ltc_usd_55_25', 'bitfinex_coinbase_pro_ltc_usd_60_25', 'bitfinex_coinbase_pro_ltc_usd_40_27', 'bitfinex_coinbase_pro_ltc_usd_45_27', 'bitfinex_coinbase_pro_ltc_usd_50_27', 'bitfinex_coinbase_pro_ltc_usd_55_27', 'bitfinex_coinbase_pro_ltc_usd_60_27', 'bitfinex_kraken_dash_usd_40_17', 'bitfinex_kraken_dash_usd_45_17', 'bitfinex_kraken_dash_usd_50_17', 'bitfinex_kraken_dash_usd_55_17', 'bitfinex_kraken_dash_usd_60_17', 'bitfinex_kraken_dash_usd_40_20', 'bitfinex_kraken_dash_usd_45_20', 'bitfinex_kraken_dash_usd_50_20', 'bitfinex_kraken_dash_usd_55_20', 'bitfinex_kraken_dash_usd_60_20', 'bitfinex_kraken_dash_usd_40_25', 'bitfinex_kraken_dash_usd_45_25', 'bitfinex_kraken_dash_usd_50_25', 'bitfinex_kraken_dash_usd_55_25', 'bitfinex_kraken_dash_usd_60_25', 'bitfinex_kraken_dash_usd_40_27', 'bitfinex_kraken_dash_usd ...

# %%
len(perf_df[perf_df['pct_profit_mean'] > -100 ])
# type(perf_df['pct_profit_mean'].iloc[50])
# perf_df['pct_profit_mean'].iloc[50]
perf_df.head(50)
# Out:
#                              ex_tp  max_features  max_depth  pct_profit_mean  \
# 0    bitfinex_coinbase_pro_xrp_usd            50         20        11.721898
# 0      coinbase_pro_hitbtc_bch_btc            60         17         9.999205
# 1    bitfinex_coinbase_pro_bch_btc            40         27         8.762994
# 0    bitfinex_coinbase_pro_bch_usd            40         17         2.722728
# 0    bitfinex_coinbase_pro_btc_usd            40         20         2.490334
# 0    bitfinex_coinbase_pro_eth_usd            60         17         1.875132
# 2    bitfinex_coinbase_pro_etc_usd            45         17         1.815758
# 1    bitfinex_coinbase_pro_ltc_usd            40         25         1.802140
# 1      coinbase_pro_hitbtc_eth_btc            40         27         1.602466
# 1          bitfinex_hitbtc_eth_btc            60         27         1.590873
# 3    bitfinex_coinbase_pro_eth_btc            50         20         1.258613
# 2      coinbase_pro_hitbtc_ltc_btc            40         17         1.089972
# 1            gemini_hitbtc_bch_btc            50         17         1.056922
# 2          bitfinex_hitbtc_xrp_btc            50         25         1.039576
# 2      coinbase_pro_gemini_bch_btc            40         20         0.981067
# 3     coinbase_pro_hitbtc_eth_usdc            45         17         0.909267
# 4          bitfinex_hitbtc_ltc_btc            45         27         0.907379
# 3          bitfinex_gemini_bch_btc            40         27         0.834138
# 5    bitfinex_coinbase_pro_ltc_btc            40         27         0.734872
# 3         bitfinex_hitbtc_bch_usdt            40         17         0.699128
# 2      coinbase_pro_gemini_ltc_btc            50         27         0.602781
# 6            kraken_hitbtc_eos_btc            40         17         0.594521
# 7         bitfinex_hitbtc_eos_usdt            40         17         0.592566
# 8            gemini_hitbtc_ltc_btc            55         17         0.477836
# 3         bitfinex_hitbtc_ltc_usdt            60         17         0.377841
# 4     coinbase_pro_kraken_dash_btc            55         27         0.352202
# 4            kraken_gemini_ltc_btc            45         20         0.330829
# 9          bitfinex_kraken_eos_btc            45         25         0.322247
# 4          bitfinex_gemini_ltc_btc            50         20         0.316826
# 10           kraken_gemini_bch_btc            40         20         0.260842
# 5         bitfinex_kraken_dash_btc            50         20         0.234934
# 11         bitfinex_kraken_eos_usd            60         17         0.207045
# 4     coinbase_pro_hitbtc_btc_usdc            45         25         0.198180
# 5      coinbase_pro_gemini_eth_btc            50         20         0.185971
# 5            gemini_hitbtc_eth_btc            40         25         0.146909
# 6          bitfinex_kraken_zec_usd            50         20         0.030384
# 6      coinbase_pro_kraken_eos_btc            40         20        -0.010174
# 7      coinbase_pro_kraken_eos_usd            50         25        -0.060776
# 7   bitfinex_coinbase_pro_dash_usd            60         17        -0.074589
# 6          bitfinex_gemini_eth_btc            50         20        -0.097887
# 12         bitfinex_hitbtc_eos_btc            45         25        -0.167227
# 13     coinbase_pro_kraken_etc_usd            45         20        -0.180015
# 8          bitfinex_kraken_etc_usd            60         20        -0.213397
# 5         bitfinex_kraken_dash_usd            40         17        -0.253386
# 9    bitfinex_coinbase_pro_zrx_usd            45         20        -0.262638
# 6     coinbase_pro_kraken_dash_usd            40         17        -0.267705
# 8          bitfinex_hitbtc_bch_btc            40         17        -0.306126
# 7         bitfinex_hitbtc_dash_btc            55         17        -0.328000
# 7     coinbase_pro_hitbtc_dash_btc            45         20        -0.371922
# 8            kraken_gemini_zec_usd            50         17        -0.390648
#
#     pct_profit_median
# 0           11.721898
# 0           11.869496
# 1           10.788925
# 0            0.153628
# 0            2.051365
# 0            0.795566
# 2            1.108093
# 1            1.779046
# 1            1.602466
# 1            1.890326
# 3            0.774013
# 2           -0.353237
# 1            0.623694
# 2            0.931033
# 2            0.688488
# 3            0.670711
# 4            0.413924
# 3            0.460741
# 5            0.162655
# 3            0.570062
# 2            0.700844
# 6            0.617855
# 7            0.496813
# 8            0.479268
# 3            0.331202
# 4            0.352202
# 4            0.352500
# 9            0.237619
# 4            0.135157
# 10           0.144773
# 5            0.234934
# 11          -0.441285
# 4            0.143440
# 5            0.185971
# 5            0.155862
# 6            0.099282
# 6           -0.081680
# 7           -0.263549
# 7           -0.074589
# 6            0.000000
# 12          -0.360198
# 13          -0.196310
# 8           -0.223869
# 5           -0.312600
# 9           -0.280626
# 6           -0.220133
# 8           -0.433675
# 7           -0.412202
# 7           -0.399994
# 8           -0.385976

# %%
def create_confusion_features(df, confusion_dict):
    
    df = df.copy()
    
    line = '-------'
    print(len(df))
    print(len(confusion_dict.keys()))
    feature_dict = {}
    model_name_list = []
    for i in range(len(df)):
        
        # define model name
        model_name = (df.ex_tp.iloc[i] + '_' + str(df.max_features.iloc[i]) 
                      + '_' + str(df.max_depth.iloc[i]))
        print(line*3 + model_name + line*3)
        model_name_list.append(model_name)
        
        # create confusion matrix for specific model
        confusion_matrix = pd.read_json(confusion_dict[model_name])
        print(confusion_matrix)

        # create confusion features
        if 'Predicted 1' in confusion_matrix.columns and 'Predicted -1' in confusion_matrix.columns:
            print('starting both')
            # % incorrect predictions for 0, 1, -1
            pct_wrong_0 = (confusion_matrix['Predicted 0'].loc[0] + 
                           confusion_matrix['Predicted 0'].loc[2])/confusion_matrix['Predicted 0'].sum()
            pct_wrong_1 = (confusion_matrix['Predicted 1'].loc[0] + 
                           confusion_matrix['Predicted 1'].loc[1])/confusion_matrix['Predicted 1'].sum()
            pct_wrong_neg1 = (confusion_matrix['Predicted -1'].loc[1] + 
                               confusion_matrix['Predicted -1'].loc[2])/confusion_matrix['Predicted -1'].sum()

            # total number correct arbitrage preds (-1)
            correct_arb_neg1 = confusion_matrix['Predicted -1'].loc[0]

            # total number correct arbitrage preds (1)
            correct_arb_1 = confusion_matrix['Predicted 1'].loc[2]
            
            # total number correct arbitrage preds (-1) + (1)
            correct_arb = correct_arb_neg1 + correct_arb_1

            # total number correct no arbitrage preds (0)
            correct_arb_0 = confusion_matrix['Predicted 0'].loc[1]


        elif 'Predicted 1' in confusion_matrix.columns:
            print('pred 1')

            pct_wrong_0 = confusion_matrix['Predicted 0'].loc[1] / confusion_matrix['Predicted 0'].sum()
            pct_wrong_1 = confusion_matrix['Predicted 1'].loc[0] / confusion_matrix['Predicted 1'].sum()
            pct_wrong_neg1 = np.nan
            print('----------------NAN---------------')

            # total number correct arbitrage preds (-1)
            correct_arb_neg1 = 0

            # total number correct arbitrage preds (1)
            correct_arb_1 = confusion_matrix['Predicted 1'].loc[1]
            
            # total number correct arbitrage preds (-1) + (1)
            correct_arb = correct_arb_neg1 + correct_arb_1

            # total number correct no arbitrage preds (0)
            correct_arb_0 = confusion_matrix['Predicted 0'].loc[0]

        elif 'Predicted -1' in confusion_matrix.columns:
            print('pred neg 1')

            pct_wrong_0 = confusion_matrix['Predicted 0'].loc[0]/confusion_matrix['Predicted 0'].sum()
            pct_wrong_1 = np.nan
            print('----------------NAN---------------')
            pct_wrong_neg1 = confusion_matrix['Predicted -1'].loc[1]/confusion_matrix['Predicted -1'].sum()

            # total number correct arbitrage preds (-1)
            correct_arb_neg1 = confusion_matrix['Predicted -1'].loc[0]

            # total number correct arbitrage preds (1)
            correct_arb_1 = 0
            
            # total number correct arbitrage preds (-1) + (1)
            correct_arb = correct_arb_neg1 + correct_arb_1

            # total number correct no arbitrage preds (0)
            correct_arb_0 = confusion_matrix['Predicted 0'].loc[1]
        
        else:
            pct_wrong_0 = 0
            pct_wrong_1 = 0
            pct_wrong_neg1 = 0
            correct_arb = 0
            correct_arb_neg1 = 0
            correct_arb_1 = 0
            correct_arb_0 = 0
            print('ERROR')

        
        # add new features to dict
        feature_list = [pct_wrong_0, pct_wrong_1, pct_wrong_neg1, correct_arb, 
                      correct_arb_neg1, correct_arb_1, correct_arb_0]
        feature_dict[model_name] = feature_list

    # create a df from the new features
    columns = ['pct_wrong_0', 'pct_wrong_1', 'pct_wrong_neg1', 'correct_arb', 
                'correct_arb_neg1', 'correct_arb_1', 'correct_arb_0']
    df2 = pd.DataFrame(feature_dict).transpose().reset_index()

    df2 = df2.rename(columns = {'index': 'model_name', 0:'pct_wrong_0', 1: 'pct_wrong_1', 
                              2: 'pct_wrong_neg1', 3: 'correct_arb', 4: 'correct_arb_neg1', 
                              5: 'correct_arb_1', 6: 'correct_arb_0'})

    print(df2.shape)
    print(len(model_name_list))
    # merge new features with performance df
    df['model_name'] = model_name_list
    print(df.shape)
    df = df.merge(df2, on='model_name')
    df.drop(columns = 'model_name', inplace=True)
    print(df.shape)
    
    return df

# %%
df = create_confusion_features(perf_df, confusion_dict)
df
# Out:
# 76
# 1520
# ---------------------bitfinex_coinbase_pro_xrp_usd_50_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           11            0
# 1             0        19651            0
# 2             0            4            1
# starting both
# ---------------------coinbase_pro_hitbtc_bch_btc_60_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0            54           16            0
# 1             3        28975            0
# 2             0           15            0
# starting both
# ---------------------bitfinex_coinbase_pro_bch_btc_40_27---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0            7            0
# 1             0        28644           17
# 2             0           31           57
# starting both
# ---------------------bitfinex_coinbase_pro_bch_usd_40_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0            10           60            0
# 1           168        28436           15
# 2             1            4           68
# starting both
# ---------------------bitfinex_coinbase_pro_btc_usd_40_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0         16615        43385            0
# 1           258        72479           73
# 2             0          238          391
# starting both
# ---------------------bitfinex_coinbase_pro_eth_usd_60_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0          9365        43321            0
# 1          1673        52483           46
# 2             0          164          285
# starting both
# ---------------------bitfinex_coinbase_pro_etc_usd_45_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             7          174            0
# 1            89        35994          102
# 2             0          342          405
# starting both
# ---------------------bitfinex_coinbase_pro_ltc_usd_40_25---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0         40316         4417            1
# 1          9796        44483           42
# 2             2          290          113
# starting both
# ---------------------coinbase_pro_hitbtc_eth_btc_40_27---------------------
#    Predicted -1  Predicted 0
# 0             0            0
# 1             1       107334
# pred neg 1
# ----------------NAN---------------
# ---------------------bitfinex_hitbtc_eth_btc_60_27---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             2           18            0
# 1             6       113217            5
# 2             0           61           18
# starting both
# ---------------------bitfinex_coinbase_pro_eth_btc_50_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           19            0
# 1             4       107211            8
# 2             0           69           24
# starting both
# ---------------------coinbase_pro_hitbtc_ltc_btc_40_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             8           21            0
# 1             4        99424            0
# 2             0            3            0
# starting both
# ---------------------gemini_hitbtc_bch_btc_50_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0           179          159            2
# 1            76         1064           32
# 2             0           53           32
# starting both
# ---------------------bitfinex_hitbtc_xrp_btc_50_25---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           17            0
# 1             0        72305            2
# 2             0           61            6
# starting both
# ---------------------coinbase_pro_gemini_bch_btc_40_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0            15           50            0
# 1            31         1092           79
# 2             2          146          182
# starting both
# ---------------------coinbase_pro_hitbtc_eth_usdc_45_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0          3939         1702            4
# 1          1168        12724          575
# 2             0         2945         1957
# starting both
# ---------------------bitfinex_hitbtc_ltc_btc_45_27---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             3           50            0
# 1             6       150863            4
# 2             0           36           16
# starting both
# ---------------------bitfinex_gemini_bch_btc_40_27---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0            20           54            0
# 1            22         1025           95
# 2             0          198          182
# starting both
# ---------------------bitfinex_coinbase_pro_ltc_btc_40_27---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           56            0
# 1             0        99322           15
# 2             0           49           18
# starting both
# ---------------------bitfinex_hitbtc_bch_usdt_40_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0           893          939            0
# 1           519         9674          385
# 2             3         2290         1100
# starting both
# ---------------------coinbase_pro_gemini_ltc_btc_50_27---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0           154          763            0
# 1            94         9810           23
# 2             0          725           33
# starting both
# ---------------------kraken_hitbtc_eos_btc_40_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             2           28            0
# 1             1         4865            0
# 2             0           26            0
# starting both
# ---------------------bitfinex_hitbtc_eos_usdt_40_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             3          372            0
# 1            15        14927           65
# 2             0          362           60
# starting both
# ---------------------gemini_hitbtc_ltc_btc_55_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0            11          740            0
# 1             7         9866           76
# 2             0          790          112
# starting both
# ---------------------bitfinex_hitbtc_ltc_usdt_60_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0           207          733            0
# 1           269        13370          225
# 2             1          720          279
# starting both
# ---------------------coinbase_pro_kraken_dash_btc_55_27---------------------
#    Predicted -1  Predicted 0
# 0             0            9
# 1             1         2117
# pred neg 1
# ----------------NAN---------------
# ---------------------kraken_gemini_ltc_btc_45_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0            47          487            0
# 1            32         2043            9
# 2             0           94           40
# starting both
# ---------------------bitfinex_kraken_eos_btc_45_25---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           30            0
# 1             0         4855            4
# 2             0           24            9
# starting both
# ---------------------bitfinex_gemini_ltc_btc_50_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0           107          823            0
# 1           126         9678           70
# 2             0          753           44
# starting both
# ---------------------kraken_gemini_bch_btc_40_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0            15          155            0
# 1            32         1088           94
# 2             1          110           86
# starting both
# ---------------------bitfinex_kraken_dash_btc_50_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           17            0
# 1             0         3005            1
# 2             0            2            0
# starting both
# ---------------------bitfinex_kraken_eos_usd_60_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           48            0
# 1             0         2833            3
# 2             0            2            0
# starting both
# ---------------------coinbase_pro_hitbtc_btc_usdc_45_25---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             9          217            0
# 1            21        24593            0
# 2             0          184            0
# starting both
# ---------------------coinbase_pro_gemini_eth_btc_50_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           84            0
# 1             0         9107            0
# 2             0          111            1
# starting both
# ---------------------gemini_hitbtc_eth_btc_40_25---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             2          100            0
# 1             4         9098            0
# 2             0           99            0
# starting both
# ---------------------bitfinex_kraken_zec_usd_50_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0            26          423            2
# 1            43         4350           28
# 2             0           35            0
# starting both
# ---------------------coinbase_pro_kraken_eos_btc_40_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           24            0
# 1             0         4844           16
# 2             0           37            1
# starting both
# ---------------------coinbase_pro_kraken_eos_usd_50_25---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           21            0
# 1             0         2836           12
# 2             0           16            1
# starting both
# ---------------------bitfinex_coinbase_pro_dash_usd_60_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0            4            0
# 1             0         2122            1
# 2             0            0            0
# starting both
# ---------------------bitfinex_gemini_eth_btc_50_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0            13           90            0
# 1            10         9055            4
# 2             0          131            0
# starting both
# ---------------------bitfinex_hitbtc_eos_btc_45_25---------------------
#    Predicted -1.0  Predicted 0.0  Predicted 1.0
# 0               1             47              0
# 1             104           2634             15
# 2               0             25              3
# ERROR
# ---------------------coinbase_pro_kraken_etc_usd_45_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           36            9
# 1             1         2426         1112
# 2             0           66          118
# starting both
# ---------------------bitfinex_kraken_etc_usd_60_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           13          141
# 1             0          757         2748
# 2             0           22           86
# starting both
# ---------------------bitfinex_kraken_dash_usd_40_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             2          228            0
# 1           259         3583            0
# 2             0           24            0
# starting both
# ---------------------bitfinex_coinbase_pro_zrx_usd_45_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0           177          310            0
# 1         11498        19322           12
# 2           131           64            0
# starting both
# ---------------------coinbase_pro_kraken_dash_usd_40_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           43            0
# 1            26         2049            0
# 2             0           10            0
# starting both
# ---------------------bitfinex_hitbtc_bch_btc_40_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0            4            0
# 1            54        28655            0
# 2             0           43            0
# starting both
# ---------------------bitfinex_hitbtc_dash_btc_55_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           96            0
# 1             0        80844         1220
# 2             0           86           51
# starting both
# ---------------------coinbase_pro_hitbtc_dash_btc_45_20---------------------
#    Predicted -1  Predicted 0
# 0             0            1
# 1           321         1805
# pred neg 1
# ----------------NAN---------------
# ---------------------kraken_gemini_zec_usd_50_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0           11            0
# 1             2         1721           85
# 2             0           48            0
# starting both
# ---------------------bitfinex_coinbase_pro_dash_btc_50_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0            0            2
# 1             0           78         2032
# 2             0            3           11
# starting both
# ---------------------bitfinex_coinbase_pro_eos_btc_50_20---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0            0            0
# 1           556        15456            0
# 2             0           22            2
# starting both
# ---------------------coinbase_pro_hitbtc_xrp_btc_40_17---------------------
#    Predicted -1  Predicted 0
# 0             0            2
# 1             0        19664
# pred neg 1
# ----------------NAN---------------
# ---------------------kraken_hitbtc_bch_btc_40_17---------------------
#    Predicted 0
# 0          972
# ERROR
# ---------------------bitfinex_hitbtc_eth_usdt_40_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0            8            0
# 1             0        18546            0
# 2             0           14            0
# starting both
# ---------------------kraken_gemini_ltc_usd_40_17---------------------
#    Predicted 0
# 0          692
# ERROR
# ---------------------bitfinex_kraken_xrp_btc_40_17---------------------
#    Predicted 0
# 0          142
# ERROR
# ---------------------coinbase_pro_gemini_bch_usd_40_17---------------------
#    Predicted -1  Predicted 0  Predicted 1
# 0             0            4            0
# 1             0          825            0
# 2             0            4            0
# starting both
# ---------------------kraken_gemini_bch_usd_40_17---------------------
#    Predicted 0
# 0          441
# ERROR
# ---------------------coinbase_pro_kraken_ltc_btc_40_17---------------------
#    Predicted -1  Predicted 0
# 0             0            1
# 1             0         2138
# pred neg 1
# ----------------NAN---------------
# ---------------------bitfinex_kraken_bch_btc_40_17---------------------
#    Predicted 0
# 0          970
# ERROR
# ---------------------kraken_hitbtc_dash_btc_40_17---------------------
#    Predicted 0  Predicted 1
# 0         3025            0
# 1            3            0
# pred 1
# ----------------NAN---------------
# ---------------------bitfinex_coinbase_pro_xrp_btc_40_17---------------------
#    Predicted 0  Predicted 1
# 0        19663            0
# 1            3            0
# pred 1
# ----------------NAN---------------
# ---------------------coinbase_pro_kraken_bch_btc_40_17---------------------
#    Predicted 0
# 0          971
# ERROR
# ---------------------coinbase_pro_gemini_ltc_usd_40_17---------------------
#    Predicted 0
# 0          447
# ERROR
# ---------------------bitfinex_kraken_ltc_btc_40_17---------------------
#    Predicted -1  Predicted 0
# 0             0            1
# 1             0         2137
# pred neg 1
# ----------------NAN---------------
# ---------------------coinbase_pro_hitbtc_eos_btc_40_17---------------------
#    Predicted -1  Predicted 0
# 0             0           20
# 1             0        16016
# pred neg 1
# ----------------NAN---------------
# ---------------------bitfinex_kraken_ltc_usd_40_17---------------------
#    Predicted 0
# 0           69
# ERROR
# ---------------------kraken_hitbtc_ltc_btc_40_17---------------------
#    Predicted 0  Predicted 1
# 0         2138            0
# 1            1            0
# pred 1
# ----------------NAN---------------
# ---------------------kraken_hitbtc_xrp_btc_40_17---------------------
#    Predicted 0
# 0          142
# ERROR
# ---------------------bitfinex_hitbtc_btc_usdt_40_17---------------------
#    Predicted 0
# 0        18568
# ERROR
# ---------------------bitfinex_gemini_zec_usd_40_17---------------------
#    Predicted -1  Predicted 0
# 0             0           23
# 1             0         1221
# pred neg 1
# ----------------NAN---------------
# ---------------------kraken_gemini_eth_btc_40_17---------------------
#    Predicted 0
# 0          184
# ERROR
# ---------------------coinbase_pro_kraken_ltc_usd_40_17---------------------
#    Predicted 0
# 0           69
# ERROR
# ---------------------coinbase_pro_kraken_xrp_btc_40_17---------------------
#    Predicted 0
# 0          142
# ERROR
# ---------------------bitfinex_gemini_bch_usd_40_17---------------------
#    Predicted -1  Predicted 0
# 0             0            8
# 1             0          825
# pred neg 1
# ----------------NAN---------------
# (76, 8)
# 76
# (76, 6)
# (76, 12)
#                             ex_tp  max_features  max_depth  pct_profit_mean  \
# 0   bitfinex_coinbase_pro_xrp_usd            50         20        11.721898
# 1     coinbase_pro_hitbtc_bch_btc            60         17         9.999205
# 2   bitfinex_coinbase_pro_bch_btc            40         27         8.762994
# 3   bitfinex_coinbase_pro_bch_usd            40         17         2.722728
# 4   bitfinex_coinbase_pro_btc_usd            40         20         2.490334
# ..                            ...           ...        ...              ...
# 71        bitfinex_gemini_zec_usd            40         17              NaN
# 72          kraken_gemini_eth_btc            40         17              NaN
# 73    coinbase_pro_kraken_ltc_usd            40         17              NaN
# 74    coinbase_pro_kraken_xrp_btc            40         17              NaN
# 75        bitfinex_gemini_bch_usd            40         17              NaN
#
#     pct_profit_median  pct_wrong_0  pct_wrong_1  pct_wrong_neg1  correct_arb  \
# 0           11.721898     0.000763     0.000000             NaN          1.0
# 1           11.869496     0.001069          NaN        0.052632         54.0
# 2           10.788925     0.001325     0.229730             NaN         57.0
# 3            0.153628     0.002246     0.180723        0.944134         78.0
# 4            2.051365     0.375730     0.157328        0.015291      17006.0
# ..                ...          ...          ...             ...          ...
# 71                NaN     0.018489          NaN             NaN          0.0
# 72                NaN     0.000000     0.000000        0.000000          0.0
# 73                NaN     0.000000     0.000000        0.000000          0.0
# 74                NaN     0.000000     0.000000        0.000000          0.0
# 75                NaN     0.009604          NaN             NaN          0.0
#
#     correct_arb_neg1  correct_arb_1  correct_arb_0
# 0                0.0            1.0        19651.0
# 1               54.0            0.0        28975.0
# 2                0.0           57.0        28644.0
# 3               10.0           68.0        28436.0
# 4            16615.0          391.0        72479.0
# ..               ...            ...            ...
# 71               0.0            0.0         1221.0
# 72               0.0            0.0            0.0
# 73               0.0            0.0            0.0
# 74               0.0            0.0            0.0
# 75               0.0            0.0          825.0
#
# [76 rows x 12 columns]

# %%
pd.set_option('display.max_rows', 500)
print(df.shape)

# filter for models that make > 0.20% profit
df2 = df[df['pct_profit_mean'] > 0.2]
print(df2.shape)

# filter for models that are predicting arb when its not happening < 20% of the time
df2 = df2[df2['pct_wrong_0'] < 0.30]
print(df2.shape)
df2

# filter for models that are predict > 100 correct arb 
df2 = df2[df2['correct_arb'] > 50]
print(df2.shape)
df2
# Out:
# (76, 12)
# (32, 12)
# (30, 12)
# (17, 12)
#                             ex_tp  max_features  max_depth  pct_profit_mean  \
# 1     coinbase_pro_hitbtc_bch_btc            60         17         9.999205
# 2   bitfinex_coinbase_pro_bch_btc            40         27         8.762994
# 3   bitfinex_coinbase_pro_bch_usd            40         17         2.722728
# 6   bitfinex_coinbase_pro_etc_usd            45         17         1.815758
# 7   bitfinex_coinbase_pro_ltc_usd            40         25         1.802140
# 12          gemini_hitbtc_bch_btc            50         17         1.056922
# 14    coinbase_pro_gemini_bch_btc            40         20         0.981067
# 15   coinbase_pro_hitbtc_eth_usdc            45         17         0.909267
# 17        bitfinex_gemini_bch_btc            40         27         0.834138
# 19       bitfinex_hitbtc_bch_usdt            40         17         0.699128
# 20    coinbase_pro_gemini_ltc_btc            50         27         0.602781
# 22       bitfinex_hitbtc_eos_usdt            40         17         0.592566
# 23          gemini_hitbtc_ltc_btc            55         17         0.477836
# 24       bitfinex_hitbtc_ltc_usdt            60         17         0.377841
# 26          kraken_gemini_ltc_btc            45         20         0.330829
# 28        bitfinex_gemini_ltc_btc            50         20         0.316826
# 29          kraken_gemini_bch_btc            40         20         0.260842
#
#     pct_profit_median  pct_wrong_0  pct_wrong_1  pct_wrong_neg1  correct_arb  \
# 1           11.869496     0.001069          NaN        0.052632         54.0
# 2           10.788925     0.001325     0.229730             NaN         57.0
# 3            0.153628     0.002246     0.180723        0.944134         78.0
# 6            1.108093     0.014133     0.201183        0.927083        412.0
# 7            1.779046     0.095690     0.275641        0.195514      40429.0
# 12           0.623694     0.166144     0.515152        0.298039        211.0
# 14           0.688488     0.152174     0.302682        0.687500        197.0
# 15           0.670711     0.267515     0.228312        0.228706       5896.0
# 17           0.460741     0.197338     0.342960        0.523810        202.0
# 19           0.570062     0.250252     0.259259        0.368905       1993.0
# 20           0.700844     0.131705     0.410714        0.379032        187.0
# 22           0.496813     0.046868     0.520000        0.833333         63.0
# 23           0.479268     0.134258     0.404255        0.388889        123.0
# 24           0.331202     0.098023     0.446429        0.566038        486.0
# 26           0.352500     0.221418     0.183673        0.405063         87.0
# 28           0.135157     0.140039     0.614035        0.540773        151.0
# 29           0.144773     0.195861     0.522222        0.687500        101.0
#
#     correct_arb_neg1  correct_arb_1  correct_arb_0
# 1               54.0            0.0        28975.0
# 2                0.0           57.0        28644.0
# 3               10.0           68.0        28436.0
# 6                7.0          405.0        35994.0
# 7            40316.0          113.0        44483.0
# 12             179.0           32.0         1064.0
# 14              15.0          182.0         1092.0
# 15            3939.0         1957.0        12724.0
# 17              20.0          182.0         1025.0
# 19             893.0         1100.0         9674.0
# 20             154.0           33.0         9810.0
# 22               3.0           60.0        14927.0
# 23              11.0          112.0         9866.0
# 24             207.0          279.0        13370.0
# 26              47.0           40.0         2043.0
# 28             107.0           44.0         9678.0
# 29              15.0           86.0         1088.0

# %% [markdown]
# ## function to create a df of features from all of the confusion matrices

# %%
def model_confusion2(confusion_dict):
    
    line = '-------'

    feature_dict = {}

    for model in confusion_dict.keys():
        
#         print(line*3 + model + line*3)
        
        # create confusion matrix for specific model
        conf_mat = pd.read_json(confusion_dict[model])
#         print(conf_mat)

        # create confusion features
        if 'Predicted 1' in conf_mat.columns and 'Predicted -1' in conf_mat.columns:

            # % incorrect predictions for 0, 1, -1
            pct_wrong_0 = (conf_mat['Predicted 0'].loc[0] + 
                           conf_mat['Predicted 0'].loc[2])/conf_mat['Predicted 0'].sum()
            pct_wrong_1 = (conf_mat['Predicted 1'].loc[0] + 
                           conf_mat['Predicted 1'].loc[1])/conf_mat['Predicted 1'].sum()
            pct_wrong_neg1 = (conf_mat['Predicted -1'].loc[1] + 
                               conf_mat['Predicted -1'].loc[2])/conf_mat['Predicted -1'].sum()

            # total number correct arbitrage preds (-1)
            correct_arb_neg1 = conf_mat['Predicted -1'].loc[0]

            # total number correct arbitrage preds (1)
            correct_arb_1 = conf_mat['Predicted 1'].loc[2]
            
            # total number correct arbitrage preds (-1) + (1)
            correct_arb = correct_arb_neg1 + correct_arb_1

            # total number correct no arbitrage preds (0)
            correct_arb_0 = conf_mat['Predicted 0'].loc[1]


        elif 'Predicted 1' in conf_mat.columns:

            pct_wrong_0 = conf_mat['Predicted 0'].loc[1] / conf_mat['Predicted 0'].sum()
            pct_wrong_1 = conf_mat['Predicted 1'].loc[0] / conf_mat['Predicted 1'].sum()
            pct_wrong_neg1 = np.nan

            # total number correct arbitrage preds (-1)
            correct_arb_neg1 = 0

            # total number correct arbitrage preds (1)
            correct_arb_1 = conf_mat['Predicted 1'].loc[1]
            
            # total number correct arbitrage preds (-1) + (1)
            correct_arb = correct_arb_neg1 + correct_arb_1

            # total number correct no arbitrage preds (0)
            correct_arb_0 = conf_mat['Predicted 0'].loc[0]

        elif 'Predicted -1' in conf_mat.columns:

            pct_wrong_0 = conf_mat['Predicted 0'].loc[0] / conf_mat['Predicted 0'].sum()
            pct_wrong_1 = np.nan
            pct_wrong_neg1 = conf_mat['Predicted -1'].loc[1] / conf_mat['Predicted -1'].sum()

            # total number correct arbitrage preds (-1)
            correct_arb_neg1 = conf_mat['Predicted -1'].loc[0]

            # total number correct arbitrage preds (1)
            correct_arb_1 = 0
            
            # total number correct arbitrage preds (-1) + (1)
            correct_arb = correct_arb_neg1 + correct_arb_1

            # total number correct no arbitrage preds (0)
            correct_arb_0 = conf_mat['Predicted 0'].loc[1]
        
        else:
            pct_wrong_0 = 0
            pct_wrong_1 = 0
            pct_wrong_neg1 = 0
            correct_arb = 0
            correct_arb_neg1 = 0
            correct_arb_1 = 0
            correct_arb_0 = 0

        
        # add new features to dict
        feature_list = [pct_wrong_0, pct_wrong_1, pct_wrong_neg1, correct_arb, 
                      correct_arb_neg1, correct_arb_1, correct_arb_0]
        feature_dict[model] = feature_list

    # create a df from the new features
    columns = ['pct_wrong_0', 'pct_wrong_1', 'pct_wrong_neg1', 'correct_arb', 
                'correct_arb_neg1', 'correct_arb_1', 'correct_arb_0']
    df = pd.DataFrame(feature_dict).transpose().reset_index()

    df = df.rename(columns = {'index': 'model_name', 0:'pct_wrong_0', 1: 'pct_wrong_1', 
                              2: 'pct_wrong_neg1', 3: 'correct_arb', 4: 'correct_arb_neg1', 
                              5: 'correct_arb_1', 6: 'correct_arb_0'})

    print('shape before filtering:', df.shape)
    
    # create max_features and max_depth columns
    df['max_features'] = [(model_name.split('_'))[-2] for model_name in df.model_name]
    df['max_depth'] = [(model_name.split('_'))[-1] for model_name in df.model_name]
    df['model_name'] = ['_'.join((model_name.split('_'))[:-2]) for model_name in df.model_name]
    
    # reorder columns
    columns = ['model_name', 'max_features', 'max_depth', 'pct_wrong_0', 
               'pct_wrong_1', 'pct_wrong_neg1', 'correct_arb', 'correct_arb_neg1', 
               'correct_arb_1', 'correct_arb_0']
    df = df[columns]
    
    # filter for models that are predicting arb when its not happening < 30% of the time
    df = df[df['pct_wrong_0'] < 0.10]
    print('shape after filetering pct_wrong_0:', df.shape)

    # filter for models that predict > 100 correct arb 
    df = df[df['correct_arb'] > 25]
    print('shape after filtering correct_arb:', df.shape)
    
    df = df.sort_values(by=['correct_arb'], ascending=False)
    df.drop_duplicates(subset='model_name', inplace=True)
    print('shape after droping duplicates:', df.shape)
    
    return df

# %%
confusion_df = model_confusion2(confusion_dict)
# Out:
# shape before filtering: (1520, 8)
# shape after filetering pct_wrong_0: (1256, 10)
# shape after filtering correct_arb: (212, 10)
# shape after droping duplicates: (16, 10)

# %%
confusion_df
# Out:
#                          model_name max_features max_depth  pct_wrong_0  \
# 90    bitfinex_coinbase_pro_ltc_usd           40        25     0.095690
# 122        bitfinex_hitbtc_ltc_usdt           50        17     0.094937
# 584   bitfinex_coinbase_pro_etc_usd           60        17     0.013515
# 1477  bitfinex_coinbase_pro_zrx_usd           50        27     0.020483
# 411        bitfinex_hitbtc_eos_usdt           45        25     0.043503
# 552     coinbase_pro_kraken_etc_usd           50        25     0.038418
# 1447        bitfinex_kraken_etc_usd           50        20     0.062121
# 1188  bitfinex_coinbase_pro_bch_usd           55        20     0.001900
# 938        bitfinex_hitbtc_dash_btc           55        27     0.002006
# 612   bitfinex_coinbase_pro_bch_btc           50        25     0.000947
# 1500    coinbase_pro_hitbtc_bch_btc           40        17     0.000655
# 349   bitfinex_coinbase_pro_eth_btc           60        20     0.000671
# 1046        bitfinex_hitbtc_eth_btc           45        20     0.000565
# 464   bitfinex_coinbase_pro_ltc_btc           60        17     0.000926
# 1258        bitfinex_kraken_zec_usd           55        27     0.095760
# 507         bitfinex_hitbtc_ltc_btc           50        20     0.000504
#
#       pct_wrong_1  pct_wrong_neg1  correct_arb  correct_arb_neg1  \
# 90       0.275641        0.195514      40429.0           40316.0
# 122      0.452865        0.564148        544.0             248.0
# 584      0.258007        0.928814        438.0              21.0
# 1477     1.000000        0.985453        196.0             196.0
# 411      0.473684        0.615385        120.0              20.0
# 552      0.895246        1.000000        119.0               0.0
# 1447     0.970389             NaN         92.0               0.0
# 1188     0.227273        0.972010         90.0              22.0
# 938      0.994142             NaN         85.0               0.0
# 612      0.706897             NaN         68.0               0.0
# 1500          NaN        0.142857         66.0              66.0
# 349      0.245283        1.000000         40.0               0.0
# 1046     0.195122        0.666667         35.0               2.0
# 464      0.641791        0.500000         31.0               7.0
# 1258     1.000000        0.785714         30.0              30.0
# 507      0.166667        0.363636         29.0              14.0
#
#       correct_arb_1  correct_arb_0
# 90            113.0        44483.0
# 122           296.0        13299.0
# 584           417.0        35766.0
# 1477            0.0        17646.0
# 411           100.0        14885.0
# 552           119.0         2528.0
# 1447           92.0          619.0
# 1188           68.0        27835.0
# 938            85.0        67651.0
# 612            68.0        28497.0
# 1500            0.0        28967.0
# 349            40.0       107200.0
# 1046           33.0       113216.0
# 464            24.0        99287.0
# 1258            0.0         4287.0
# 507            15.0       150862.0

# %%
columns = ['pct_wrong_0', 'pct_wrong_1', 'pct_wrong_neg1', 'correct_arb', 
                  'correct_arb_neg1', 'correct_arb_1', 'correct_arb_0']
df = pd.DataFrame(pct_wrong_0_dict).transpose().reset_index()

df = df.rename(columns = {'index': 'model_name', 0:'pct_wrong_0', 1: 'pct_wrong_1', 
                     2: 'pct_wrong_neg1', 3: 'correct_arb', 4: 'correct_arb_neg1', 
                     5: 'correct_arb_1', 6: 'correct_arb_0'})
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-7fcdd5588b46> in <module>
#       1 columns = ['pct_wrong_0', 'pct_wrong_1', 'pct_wrong_neg1', 'correct_arb',
#       2                   'correct_arb_neg1', 'correct_arb_1', 'correct_arb_0']
# ----> 3 df = pd.DataFrame(pct_wrong_0_dict).transpose().reset_index()
#       4
#       5 df = df.rename(columns = {'index': 'model_name', 0:'pct_wrong_0', 1: 'pct_wrong_1',
#
# NameError: name 'pct_wrong_0_dict' is not defined

# %% [markdown]
# ## function for creating df with pnl and confusion matrix features

# %%
def model_confusion(df, confusion_dict):
    
    # create a copy of df to not overwrite original
    df = df.copy()
    
    line = '-------'
    feature_dict = {}
    model_name_list = []
    
    # iterate through all models
    for i in range(len(df)):
        
        # define model name
        model_name = (df.ex_tp.iloc[i] + '_' + str(df.max_features.iloc[i]) 
                      + '_' + str(df.max_depth.iloc[i]) + '_' + str(df.n_estimators.iloc[i]))
        model_name_list.append(model_name)
        
        # create confusion matrix for specific model
        conf_mat = pd.read_json(confusion_dict[model_name])

        #########################################################
        ############## create confusion features ################
        #########################################################
        
        # confusion matrix has -1, 0, 1 predictions
        if 'Predicted 1' in conf_mat.columns and 'Predicted -1' in conf_mat.columns:

            # % incorrect predictions for 0, 1, -1
            pct_wrong_0 = (conf_mat['Predicted 0'].loc[0] + 
                           conf_mat['Predicted 0'].loc[2])/conf_mat['Predicted 0'].sum()
            pct_wrong_1 = (conf_mat['Predicted 1'].loc[0] + 
                           conf_mat['Predicted 1'].loc[1])/conf_mat['Predicted 1'].sum()
            pct_wrong_neg1 = (conf_mat['Predicted -1'].loc[1] + 
                               conf_mat['Predicted -1'].loc[2])/conf_mat['Predicted -1'].sum()

            # total number correct arbitrage preds (-1)
            correct_arb_neg1 = conf_mat['Predicted -1'].loc[0]

            # total number correct arbitrage preds (1)
            correct_arb_1 = conf_mat['Predicted 1'].loc[2]
            
            # total number correct arbitrage preds (-1) + (1)
            correct_arb = correct_arb_neg1 + correct_arb_1

            # total number correct no arbitrage preds (0)
            correct_arb_0 = conf_mat['Predicted 0'].loc[1]

        # confusion matrix has 0, 1 predictions
        elif 'Predicted 1' in conf_mat.columns:

            pct_wrong_0 = conf_mat['Predicted 0'].loc[1] / conf_mat['Predicted 0'].sum()
            pct_wrong_1 = conf_mat['Predicted 1'].loc[0] / conf_mat['Predicted 1'].sum()
            pct_wrong_neg1 = np.nan

            # total number correct arbitrage preds (-1)
            correct_arb_neg1 = 0

            # total number correct arbitrage preds (1)
            correct_arb_1 = conf_mat['Predicted 1'].loc[1]
            
            # total number correct arbitrage preds (-1) + (1)
            correct_arb = correct_arb_neg1 + correct_arb_1

            # total number correct no arbitrage preds (0)
            correct_arb_0 = conf_mat['Predicted 0'].loc[0]
        
        # confusion matrix has -1, 0 predictions
        elif 'Predicted -1' in conf_mat.columns:

            pct_wrong_0 = conf_mat['Predicted 0'].loc[0] / conf_mat['Predicted 0'].sum()
            pct_wrong_1 = np.nan
            pct_wrong_neg1 = conf_mat['Predicted -1'].loc[1] / conf_mat['Predicted -1'].sum()

            # total number correct arbitrage preds (-1)
            correct_arb_neg1 = conf_mat['Predicted -1'].loc[0]

            # total number correct arbitrage preds (1)
            correct_arb_1 = 0
            
            # total number correct arbitrage preds (-1) + (1)
            correct_arb = correct_arb_neg1 + correct_arb_1

            # total number correct no arbitrage preds (0)
            correct_arb_0 = conf_mat['Predicted 0'].loc[1]
        
        # confusion matrix has only 0
        else:
            pct_wrong_0 = 0
            pct_wrong_1 = 0
            pct_wrong_neg1 = 0
            correct_arb = 0
            correct_arb_neg1 = 0
            correct_arb_1 = 0
            correct_arb_0 = 0

        
        # add confusion features to dict
        feature_list = [correct_arb, pct_wrong_0, pct_wrong_1, pct_wrong_neg1, 
                        correct_arb_neg1, correct_arb_1, correct_arb_0]
        feature_dict[model_name] = feature_list

    # create a df from the new features
    columns = ['correct_arb', 'pct_wrong_0', 'pct_wrong_1', 'pct_wrong_neg1', 
                'correct_arb_neg1', 'correct_arb_1', 'correct_arb_0']
    df2 = pd.DataFrame(feature_dict).transpose().reset_index()
    df2 = df2.rename(columns = {'index': 'model_name', 0: 'correct_arb', 1:'pct_wrong_0', 
                                2: 'pct_wrong_1', 3: 'pct_wrong_neg1', 
                                4: 'correct_arb_neg1', 5: 'correct_arb_1', 
                                6: 'correct_arb_0'})
    
    # merge new features with performance df
    df['model_name'] = model_name_list
    print(df.shape, df2.shape)
    df = df.merge(df2, on='model_name').drop(columns = 'model_name')
    print('shape after merge:', df.shape)

    # filter for models that are predicting arb when its not happening < 15% of the time
    df = df[df['pct_wrong_0'] < 0.15]
    print('shape after filetering pct_wrong_0:', df.shape)

    # filter for models that predict > 25 correct arb 
    df = df[df['correct_arb'] > 25]
    print('shape after filtering correct_arb:', df.shape)
    
    # filter for models that make > 0.20% profit
    df = df[df['pct_profit_mean'] > 0.2]
    print('shape after filtering pct_profit_mean:', df.shape)
    
    df = df.sort_values(by=['correct_arb'], ascending=False)
    df2 = df.drop_duplicates(subset='ex_tp')
    print('shape after droping duplicates:', df2.shape)
    
    
    return df, df2

# %%
df, df2 = model_confusion(perf_df, confusion_dict)
df2
# Out:
# (76, 6) (76, 8)
# shape after merge: (76, 12)
# shape after filetering pct_wrong_0: (67, 12)
# shape after filtering correct_arb: (15, 12)
# shape after filtering pct_profit_mean: (10, 12)
# shape after droping duplicates: (10, 12)
#                             ex_tp  max_features  max_depth  pct_profit_mean  \
# 7   bitfinex_coinbase_pro_ltc_usd            40         25         1.802140
# 24       bitfinex_hitbtc_ltc_usdt            60         17         0.377841
# 6   bitfinex_coinbase_pro_etc_usd            45         17         1.815758
# 20    coinbase_pro_gemini_ltc_btc            50         27         0.602781
# 28        bitfinex_gemini_ltc_btc            50         20         0.316826
# 23          gemini_hitbtc_ltc_btc            55         17         0.477836
# 3   bitfinex_coinbase_pro_bch_usd            40         17         2.722728
# 22       bitfinex_hitbtc_eos_usdt            40         17         0.592566
# 2   bitfinex_coinbase_pro_bch_btc            40         27         8.762994
# 1     coinbase_pro_hitbtc_bch_btc            60         17         9.999205
#
#     pct_profit_median  correct_arb  pct_wrong_0  pct_wrong_1  pct_wrong_neg1  \
# 7            1.779046      40429.0     0.095690     0.275641        0.195514
# 24           0.331202        486.0     0.098023     0.446429        0.566038
# 6            1.108093        412.0     0.014133     0.201183        0.927083
# 20           0.700844        187.0     0.131705     0.410714        0.379032
# 28           0.135157        151.0     0.140039     0.614035        0.540773
# 23           0.479268        123.0     0.134258     0.404255        0.388889
# 3            0.153628         78.0     0.002246     0.180723        0.944134
# 22           0.496813         63.0     0.046868     0.520000        0.833333
# 2           10.788925         57.0     0.001325     0.229730             NaN
# 1           11.869496         54.0     0.001069          NaN        0.052632
#
#     correct_arb_neg1  correct_arb_1  correct_arb_0
# 7            40316.0          113.0        44483.0
# 24             207.0          279.0        13370.0
# 6                7.0          405.0        35994.0
# 20             154.0           33.0         9810.0
# 28             107.0           44.0         9678.0
# 23              11.0          112.0         9866.0
# 3               10.0           68.0        28436.0
# 22               3.0           60.0        14927.0
# 2                0.0           57.0        28644.0
# 1               54.0            0.0        28975.0

# %%
perf_df
# Out:
#                              ex_tp  max_features  max_depth  pct_profit_mean  \
# 0    bitfinex_coinbase_pro_xrp_usd            50         20        11.721898
# 0      coinbase_pro_hitbtc_bch_btc            60         17         9.999205
# 1    bitfinex_coinbase_pro_bch_btc            40         27         8.762994
# 0    bitfinex_coinbase_pro_bch_usd            40         17         2.722728
# 0    bitfinex_coinbase_pro_btc_usd            40         20         2.490334
# 0    bitfinex_coinbase_pro_eth_usd            60         17         1.875132
# 2    bitfinex_coinbase_pro_etc_usd            45         17         1.815758
# 1    bitfinex_coinbase_pro_ltc_usd            40         25         1.802140
# 1      coinbase_pro_hitbtc_eth_btc            40         27         1.602466
# 1          bitfinex_hitbtc_eth_btc            60         27         1.590873
# 3    bitfinex_coinbase_pro_eth_btc            50         20         1.258613
# 2      coinbase_pro_hitbtc_ltc_btc            40         17         1.089972
# 1            gemini_hitbtc_bch_btc            50         17         1.056922
# 2          bitfinex_hitbtc_xrp_btc            50         25         1.039576
# 2      coinbase_pro_gemini_bch_btc            40         20         0.981067
# 3     coinbase_pro_hitbtc_eth_usdc            45         17         0.909267
# 4          bitfinex_hitbtc_ltc_btc            45         27         0.907379
# 3          bitfinex_gemini_bch_btc            40         27         0.834138
# 5    bitfinex_coinbase_pro_ltc_btc            40         27         0.734872
# 3         bitfinex_hitbtc_bch_usdt            40         17         0.699128
# 2      coinbase_pro_gemini_ltc_btc            50         27         0.602781
# 6            kraken_hitbtc_eos_btc            40         17         0.594521
# 7         bitfinex_hitbtc_eos_usdt            40         17         0.592566
# 8            gemini_hitbtc_ltc_btc            55         17         0.477836
# 3         bitfinex_hitbtc_ltc_usdt            60         17         0.377841
# 4     coinbase_pro_kraken_dash_btc            55         27         0.352202
# 4            kraken_gemini_ltc_btc            45         20         0.330829
# 9          bitfinex_kraken_eos_btc            45         25         0.322247
# 4          bitfinex_gemini_ltc_btc            50         20         0.316826
# 10           kraken_gemini_bch_btc            40         20         0.260842
# 5         bitfinex_kraken_dash_btc            50         20         0.234934
# 11         bitfinex_kraken_eos_usd            60         17         0.207045
# 4     coinbase_pro_hitbtc_btc_usdc            45         25         0.198180
# 5      coinbase_pro_gemini_eth_btc            50         20         0.185971
# 5            gemini_hitbtc_eth_btc            40         25         0.146909
# 6          bitfinex_kraken_zec_usd            50         20         0.030384
# 6      coinbase_pro_kraken_eos_btc            40         20        -0.010174
# 7      coinbase_pro_kraken_eos_usd            50         25        -0.060776
# 7   bitfinex_coinbase_pro_dash_usd            60         17        -0.074589
# 6          bitfinex_gemini_eth_btc            50         20        -0.097887
# 12         bitfinex_hitbtc_eos_btc            45         25        -0.167227
# 13     coinbase_pro_kraken_etc_usd            45         20        -0.180015
# 8          bitfinex_kraken_etc_usd            60         20        -0.213397
# 5         bitfinex_kraken_dash_usd            40         17        -0.253386
# 9    bitfinex_coinbase_pro_zrx_usd            45         20        -0.262638
# 6     coinbase_pro_kraken_dash_usd            40         17        -0.267705
# 8          bitfinex_hitbtc_bch_btc            40         17        -0.306126
# 7         bitfinex_hitbtc_dash_btc            55         17        -0.328000
# 7     coinbase_pro_hitbtc_dash_btc            45         20        -0.371922
# 8            kraken_gemini_zec_usd            50         17        -0.390648
# 9   bitfinex_coinbase_pro_dash_btc            50         17        -0.396240
# 14   bitfinex_coinbase_pro_eos_btc            50         20        -0.467505
# 10     coinbase_pro_hitbtc_xrp_btc            40         17              NaN
# 11           kraken_hitbtc_bch_btc            40         17              NaN
# 12        bitfinex_hitbtc_eth_usdt            40         17              NaN
# 13           kraken_gemini_ltc_usd            40         17              NaN
# 14         bitfinex_kraken_xrp_btc            40         17              NaN
# 15     coinbase_pro_gemini_bch_usd            40         17              NaN
# 16           kraken_gemini_bch_usd            40         17              NaN
# 15     coinbase_pro_kraken_ltc_btc            40         17              NaN
# 16         bitfinex_kraken_bch_btc            40         17              NaN
# 10          kraken_hitbtc_dash_btc            40         17              NaN
# 11   bitfinex_coinbase_pro_xrp_btc            40         17              NaN
# 12     coinbase_pro_kraken_bch_btc            40         17              NaN
# 8      coinbase_pro_gemini_ltc_usd            40         17              NaN
# 9          bitfinex_kraken_ltc_btc            40         17              NaN
# 10     coinbase_pro_hitbtc_eos_btc            40         17              NaN
# 11         bitfinex_kraken_ltc_usd            40         17              NaN
# 12           kraken_hitbtc_ltc_btc            40         17              NaN
# 13           kraken_hitbtc_xrp_btc            40         17              NaN
# 9         bitfinex_hitbtc_btc_usdt            40         17              NaN
# 10         bitfinex_gemini_zec_usd            40         17              NaN
# 11           kraken_gemini_eth_btc            40         17              NaN
# 12     coinbase_pro_kraken_ltc_usd            40         17              NaN
# 13     coinbase_pro_kraken_xrp_btc            40         17              NaN
# 14         bitfinex_gemini_bch_usd            40         17              NaN
#
#     pct_profit_median
# 0           11.721898
# 0           11.869496
# 1           10.788925
# 0            0.153628
# 0            2.051365
# 0            0.795566
# 2            1.108093
# 1            1.779046
# 1            1.602466
# 1            1.890326
# 3            0.774013
# 2           -0.353237
# 1            0.623694
# 2            0.931033
# 2            0.688488
# 3            0.670711
# 4            0.413924
# 3            0.460741
# 5            0.162655
# 3            0.570062
# 2            0.700844
# 6            0.617855
# 7            0.496813
# 8            0.479268
# 3            0.331202
# 4            0.352202
# 4            0.352500
# 9            0.237619
# 4            0.135157
# 10           0.144773
# 5            0.234934
# 11          -0.441285
# 4            0.143440
# 5            0.185971
# 5            0.155862
# 6            0.099282
# 6           -0.081680
# 7           -0.263549
# 7           -0.074589
# 6            0.000000
# 12          -0.360198
# 13          -0.196310
# 8           -0.223869
# 5           -0.312600
# 9           -0.280626
# 6           -0.220133
# 8           -0.433675
# 7           -0.412202
# 7           -0.399994
# 8           -0.385976
# 9           -0.416532
# 14          -0.509385
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 15                NaN
# 16                NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
