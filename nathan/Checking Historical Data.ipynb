# %%
import pandas as pd

coinbase_df = pd.read_csv('Priority_1/coinbase/coinbase_mana_usdc.csv', index_col=0)
bitfinex_df = pd.read_csv('Priority_1/bitfinex/bitfinex_mana_usd.csv', index_col=0)
poloniex_df = pd.read_csv('Priority_1/poloniex/poloniex_mana_usdt.csv', index_col=0)

# %%
bitfinex_df
# Out:
#              time      open      high       low     close         volume
# 0      1569848700  0.026037  0.026037  0.026037  0.026037    1954.685123
# 1      1569673200  0.026037  0.026037  0.026037  0.026037     199.600000
# 2      1569663900  0.025886  0.025886  0.025886  0.025886     499.500000
# 3      1569515100  0.024812  0.024812  0.024812  0.024812     200.000000
# 4      1569504600  0.028095  0.028095  0.028095  0.028095    4369.032394
# 5      1569493500  0.029000  0.029000  0.029000  0.029000     459.260921
# 6      1569493200  0.029000  0.029000  0.029000  0.029000   33124.414611
# 7      1569492000  0.029000  0.029000  0.029000  0.029000   17575.451122
# 8      1569430500  0.025565  0.025565  0.025565  0.025565     999.000000
# 9      1569364500  0.025979  0.025979  0.025979  0.025979     139.860000
# 10     1569363300  0.029000  0.029000  0.029000  0.029000    4000.000000
# 11     1569357900  0.028930  0.028930  0.028930  0.028930     110.631938
# ...

# %%
poloniex_df
# Out:
#               time      open      high       low     close      volume
# 0       1569024000  0.034500  0.034500  0.034500  0.034500    0.000000
# 1       1569024300  0.034500  0.034500  0.034500  0.034500    0.000000
# 2       1569024600  0.034500  0.034500  0.034500  0.034500    0.000000
# 3       1569024900  0.034500  0.034500  0.034500  0.034500    0.000000
# 4       1569025200  0.034500  0.034500  0.034500  0.034500    0.000000
# 5       1569025500  0.034500  0.034500  0.034500  0.034500    0.000000
# 6       1569025800  0.034500  0.034500  0.034500  0.034500    0.000000
# 7       1569026100  0.034500  0.034500  0.034500  0.034500    0.000000
# 8       1569026400  0.034500  0.034500  0.034500  0.034500    0.000000
# 9       1569026700  0.034500  0.034500  0.034500  0.034500    0.000000
# 10      1569027000  0.034500  0.034500  0.034500  0.034500    0.000000
# 11      1569027300  0.034500  0.034500  0.034500  0.034500    0.000000
# ...

# %%
coinbase_df
# Out:
#              time      open      high       low     close  volume
# 0      1569888000  0.027373  0.027373  0.027070  0.027070    2081
# 1      1569886800  0.027373  0.027373  0.027070  0.027070      16
# 2      1569885900  0.027358  0.027373  0.027071  0.027373    5018
# 3      1569885600  0.027302  0.027373  0.027302  0.027373   15001
# 4      1569884100  0.027280  0.027311  0.027280  0.027311      13
# 5      1569883200  0.027000  0.027308  0.027000  0.027308      21
# 6      1569882600  0.027338  0.027338  0.027338  0.027338      12
# 7      1569882300  0.027031  0.027339  0.027031  0.027339      30
# 8      1569881400  0.027339  0.027339  0.027338  0.027338      29
# 9      1569880500  0.027339  0.027339  0.027339  0.027339     346
# 10     1569879900  0.027000  0.027183  0.027000  0.027183    1514
# 11     1569879600  0.027000  0.027000  0.027000  0.027000    2458
# 12     1569879300  0.027238  0.027238  0.027000  0.027178    1492
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))

plt.plot(coinbase_df['time'], coinbase_df['close'], linewidth=.5, alpha=0.75, color='blue')
plt.plot(bitfinex_df['time'], bitfinex_df['close'], linewidth=.5, alpha=0.75, color='red')
plt.plot(poloniex_df['time'], poloniex_df['close'], linewidth=.5, alpha=0.75, color='yellow')
