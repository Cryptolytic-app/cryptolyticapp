# %%
# !pip install psycopg2

# %%
import psycopg2 as ps
import requests
import pandas as pd

# %%
# Total number of tables equals 65.

table_list = ["bitfinex_bchbtc",
 "bitfinex_bchusd",
 "bitfinex_btcusd",
 "bitfinex_btcusdt",
 "bitfinex_dashbtc",
 "bitfinex_dashusd",
 "bitfinex_eosbtc",
 "bitfinex_eosusd",
 "bitfinex_eosusdt",
 "bitfinex_etcbtc",
 "bitfinex_etcusd",
 "bitfinex_ethbtc",
 "bitfinex_ethusd",
 "bitfinex_ltcbtc",
 "bitfinex_ltcusd",
 "bitfinex_xlmusd",
 "bitfinex_xrpbtc",
 "bitfinex_xrpusd",
 "bitfinex_zecbtc",
 "bitfinex_zecusd",
 "coinbase_pro_bchbtc",
 "coinbase_pro_bchusd",
 "coinbase_pro_btcusd",
 "coinbase_pro_btcusdc",
 "coinbase_pro_dashbtc",
 "coinbase_pro_dashusd",
 "coinbase_pro_eosbtc",
 "coinbase_pro_eosusd",
 "coinbase_pro_etcbtc",
 "coinbase_pro_etcusd",
 "coinbase_pro_ethbtc",
 "coinbase_pro_ethusd",
 "coinbase_pro_ethusdc",
 "coinbase_pro_ltcbtc",
 "coinbase_pro_ltcusd",
 "coinbase_pro_xlmusd",
 "coinbase_pro_xrpbtc",
 "coinbase_pro_xrpusd",
 "coinbase_pro_zecbtc",
 "coinbase_pro_zecusdc",
 "poloniex_bchbtc",
 "poloniex_bchusdc",
 "poloniex_btcusdc",
 "poloniex_btcusdt",
 "poloniex_dashbtc",
 "poloniex_dashusdc",
 "poloniex_dashusdt",
 "poloniex_eosbtc",
 "poloniex_eosusdc",
 "poloniex_eosusdt",
 "poloniex_etcbtc",
 "poloniex_etcusdt",
 "poloniex_ethbtc",
 "poloniex_ethusdc",
 "poloniex_ethusdt",
 "poloniex_ltcbtc",
 "poloniex_ltcusdc",
 "poloniex_xlmusdc",
 "poloniex_xlmusdt",
 "poloniex_xrpbtc",
 "poloniex_xrpusdc",
 "poloniex_xrpusdt",
 "poloniex_zecbtc",
 "poloniex_zecusdc",
 "poloniex_zecusdt"]

# %%
# Define credentials.

credentials = {'POSTGRES_ADDRESS' : '#',
               'POSTGRES_PORT' : '#',
               'POSTGRES_USERNAME' : '#',
               'POSTGRES_PASSWORD' : '#',
               'POSTGRES_DBNAME' : '#',
               'API_KEY' : '#'}

# %%
# Create 65 tables in database specific to fiveminute schema.

# Create connection.
  
conn = ps.connect(host=credentials['POSTGRES_ADDRESS'],
                  port=credentials['POSTGRES_PORT'],
                  user=credentials['POSTGRES_USERNAME'],
                  password=credentials['POSTGRES_PASSWORD'],
                  database=credentials['POSTGRES_DBNAME'])

# Create a cursor.
  
cur = conn.cursor()

# Loop through table_list.

for table_name in table_list:
  cur.execute('''
    CREATE TABLE fiveminute.{table_name}
     (
     time integer,
     open float,
     high float,
     low float,
     close float,
     volume float
     );'''.format(table_name=table_name))

# Commit and close. Verify that table was created successfully.

conn.commit()

print("Tables created successfully!")

conn.close()
# Out:
# Tables created successfully!

# %%
# Create 65 tables in database specific to onehour schema.

# Create connection.
  
conn = ps.connect(host=credentials['POSTGRES_ADDRESS'],
                  port=credentials['POSTGRES_PORT'],
                  user=credentials['POSTGRES_USERNAME'],
                  password=credentials['POSTGRES_PASSWORD'],
                  database=credentials['POSTGRES_DBNAME'])

# Create a cursor.
  
cur = conn.cursor()

# Loop through table_list.

for table_name in table_list:
  cur.execute('''
    CREATE TABLE onehour.{table_name}
     (
     time integer,
     open float,
     high float,
     low float,
     close float,
     volume float
     );'''.format(table_name=table_name))

# Commit and close. Verify that table was created successfully.

conn.commit()

print("Tables created successfully!")

conn.close()
# Out:
# Tables created successfully!

# %%
# TRUNCATE command for fiveminute schema to remove all data within tables.

TRUNCATE fiveminute.bitfinex_bchbtc,
 fiveminute.bitfinex_bchusd,
 fiveminute.bitfinex_btcusd,
 fiveminute.bitfinex_btcusdt,
 fiveminute.bitfinex_dashbtc,
 fiveminute.bitfinex_dashusd,
 fiveminute.bitfinex_eosbtc,
 fiveminute.bitfinex_eosusd,
 fiveminute.bitfinex_eosusdt,
 fiveminute.bitfinex_etcbtc,
 fiveminute.bitfinex_etcusd,
 fiveminute.bitfinex_ethbtc,
 fiveminute.bitfinex_ethusd,
 fiveminute.bitfinex_ltcbtc,
 fiveminute.bitfinex_ltcusd,
 fiveminute.bitfinex_xlmusd,
 fiveminute.bitfinex_xrpbtc,
 fiveminute.bitfinex_xrpusd,
 fiveminute.bitfinex_zecbtc,
 fiveminute.bitfinex_zecusd,
 fiveminute.coinbase_pro_bchbtc,
 fiveminute.coinbase_pro_bchusd,
 fiveminute.coinbase_pro_btcusd,
 fiveminute.coinbase_pro_btcusdc,
 fiveminute.coinbase_pro_dashbtc,
 fiveminute.coinbase_pro_dashusd,
 fiveminute.coinbase_pro_eosbtc,
 fiveminute.coinbase_pro_eosusd,
 fiveminute.coinbase_pro_etcbtc,
 fiveminute.coinbase_pro_etcusd,
 fiveminute.coinbase_pro_ethbtc,
 fiveminute.coinbase_pro_ethusd,
 fiveminute.coinbase_pro_ethusdc,
 fiveminute.coinbase_pro_ltcbtc,
 fiveminute.coinbase_pro_ltcusd,
 fiveminute.coinbase_pro_xlmusd,
 fiveminute.coinbase_pro_xrpbtc,
 fiveminute.coinbase_pro_xrpusd,
 fiveminute.coinbase_pro_zecbtc,
 fiveminute.coinbase_pro_zecusdc,
 fiveminute.poloniex_bchbtc,
 fiveminute.poloniex_bchusdc,
 fiveminute.poloniex_btcusdc,
 fiveminute.poloniex_btcusdt,
 fiveminute.poloniex_dashbtc,
 fiveminute.poloniex_dashusdc,
 fiveminute.poloniex_dashusdt,
 fiveminute.poloniex_eosbtc,
 fiveminute.poloniex_eosusdc,
 fiveminute.poloniex_eosusdt,
 fiveminute.poloniex_etcbtc,
 fiveminute.poloniex_etcusdt,
 fiveminute.poloniex_ethbtc,
 fiveminute.poloniex_ethusdc,
 fiveminute.poloniex_ethusdt,
 fiveminute.poloniex_ltcbtc,
 fiveminute.poloniex_ltcusdc,
 fiveminute.poloniex_xlmusdc,
 fiveminute.poloniex_xlmusdt,
 fiveminute.poloniex_xrpbtc,
 fiveminute.poloniex_xrpusdc,
 fiveminute.poloniex_xrpusdt,
 fiveminute.poloniex_zecbtc,
 fiveminute.poloniex_zecusdc,
 fiveminute.poloniex_zecusdt;

# %%
# TRUNCATE command for onehour schema to remove all data within tables.

TRUNCATE onehour.bitfinex_bchbtc,
 onehour.bitfinex_bchusd,
 onehour.bitfinex_btcusd,
 onehour.bitfinex_btcusdt,
 onehour.bitfinex_dashbtc,
 onehour.bitfinex_dashusd,
 onehour.bitfinex_eosbtc,
 onehour.bitfinex_eosusd,
 onehour.bitfinex_eosusdt,
 onehour.bitfinex_etcbtc,
 onehour.bitfinex_etcusd,
 onehour.bitfinex_ethbtc,
 onehour.bitfinex_ethusd,
 onehour.bitfinex_ltcbtc,
 onehour.bitfinex_ltcusd,
 onehour.bitfinex_xlmusd,
 onehour.bitfinex_xrpbtc,
 onehour.bitfinex_xrpusd,
 onehour.bitfinex_zecbtc,
 onehour.bitfinex_zecusd,
 onehour.coinbase_pro_bchbtc,
 onehour.coinbase_pro_bchusd,
 onehour.coinbase_pro_btcusd,
 onehour.coinbase_pro_btcusdc,
 onehour.coinbase_pro_dashbtc,
 onehour.coinbase_pro_dashusd,
 onehour.coinbase_pro_eosbtc,
 onehour.coinbase_pro_eosusd,
 onehour.coinbase_pro_etcbtc,
 onehour.coinbase_pro_etcusd,
 onehour.coinbase_pro_ethbtc,
 onehour.coinbase_pro_ethusd,
 onehour.coinbase_pro_ethusdc,
 onehour.coinbase_pro_ltcbtc,
 onehour.coinbase_pro_ltcusd,
 onehour.coinbase_pro_xlmusd,
 onehour.coinbase_pro_xrpbtc,
 onehour.coinbase_pro_xrpusd,
 onehour.coinbase_pro_zecbtc,
 onehour.coinbase_pro_zecusdc,
 onehour.poloniex_bchbtc,
 onehour.poloniex_bchusdc,
 onehour.poloniex_btcusdc,
 onehour.poloniex_btcusdt,
 onehour.poloniex_dashbtc,
 onehour.poloniex_dashusdc,
 onehour.poloniex_dashusdt,
 onehour.poloniex_eosbtc,
 onehour.poloniex_eosusdc,
 onehour.poloniex_eosusdt,
 onehour.poloniex_etcbtc,
 onehour.poloniex_etcusdt,
 onehour.poloniex_ethbtc,
 onehour.poloniex_ethusdc,
 onehour.poloniex_ethusdt,
 onehour.poloniex_ltcbtc,
 onehour.poloniex_ltcusdc,
 onehour.poloniex_xlmusdc,
 onehour.poloniex_xlmusdt,
 onehour.poloniex_xrpbtc,
 onehour.poloniex_xrpusdc,
 onehour.poloniex_xrpusdt,
 onehour.poloniex_zecbtc,
 onehour.poloniex_zecusdc,
 onehour.poloniex_zecusdt;
